# %%
import re
import pandas as pd
#from pandas import DataFrame,Series

# %%
data_source = pd.read_excel('小区列表.xlsx')

data_source.head()

data_source.name.tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0            骆驼湾
# 1         融城昆明湖
# 2         中建龙熙一号
# 3          新时代广场
# 4         绿城春江明月
# 5           中梁首府
# 6          俊发盛唐城
# 7          远洋青云府
# 8        瑞鼎城二期天玺
# 9           新迎新城
# 10          东原璞阅
# 11         碧桂园璟台
# 12          瀚林澜山
# 13        中海云麓九里
# 14            奥园
# 15          融城春晓
# 16        世豪香颂时光
# 17        耀兴枫丹白露
# 18       实地昆明花鹤翎
# 19        新希望白麓城
# 20          和悦铭著
# 21          君庭云邸
# 22          金泰国际
# 23       西城时代西锦里
# 24    金泰国际III期名门
# 25      假日城市二期芳华
# 26         德润香山府
# 27           万彩城
# 28       碧桂园龙腾世家
# 29         英茂瑞景园
#          ...
# 32            润城
# 33       佳兆业壹号公馆
# 34       北科建春城大观
# 35        恒泰滇池名门
# 36        新希望观澜汇
# 37         筑友双河湾
# 38           南悦城
# 39        万科银海泊岸
# 40          海伦国际
# 41          红星天铂
# 42          龙湖半山
# 43         实力锦雲府
# 44      昆明呈贡吾悦广场
# 45         绿地东海岸
# 46      昆明国贸国际新城
# 47      中通世纪峯荟花园
# 48          泛亚城邦
# 49        招商翰林大观
# 50          光明璟宸
# 51         广电苑和园
# 52        融创微风十里
# 53       华侨城公园悦府
# 54    北大资源颐和1898
# 55        东骧神骏二期
# 56      领秀知识城国门府
# 57          兰亭广场
# 58         金科江湖海
# 59          大观首府
# 60          翰林澜山
# 61      中交金地中央公园
# Name: name, Length: 62, dtype: object>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_search = 'https://km.fang.anjuke.com/loupan/s?kw='
#type(data_source.columns)

kw = {'kw':'融城昆明湖'}

headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:67.0) Gecko/20100101 Firefox/67.0'}
response = requests.get("https://km.fang.anjuke.com/loupan/s?",params = kw, headers = headers)

# 查看响应码
print(response.status_code)


#查看响应页面内容
#print(response.text )

html_text = response.text 
soup = BeautifulSoup(html_text,"html.parser")
# Out:
# 200

# %%
find_url = soup.find_all('a',class_ = 'lp-name')

#print(find_url[0])
final_url = find_url[0].get('href')

print(final_url)
# Out:
# https://km.fang.anjuke.com/loupan/255696.html

# %%
response = requests.get(final_url,headers = headers)

# 查看响应码
print(response.status_code)

#查看响应页面内容
#print(response.text )

html_text = response.text 
soup = BeautifulSoup(html_text,"html.parser")
print(html_text)
# Out:
# 200
#
#
#
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <title>融城昆明湖，昆明融城昆明湖房价，楼盘户型，周边配套，交通地图，龙江西路,近盘江西路 - 安居客</title>
#     <meta name="keywords" content="融城昆明湖,昆明湖" />
# <meta name="description" content="安居客为您提供昆明融城昆明湖楼盘详情信息，融城昆明湖房价走势，融城昆明湖户型图，融城昆明湖周边配套，了解更多该楼盘信息，就上安居客。" />
# <link rel="canonical" href="https://km.fang.anjuke.com/loupan/255696.html" >
# <link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.anjuke.com/km/loupan/255696/" >
#     <meta name="mobile-agent" content="format=html5;url=https://m.anjuke.com/km/loupan/255696/" />
# <meta http-equiv = "X-UA-Compatible" content = "IE=edge,chrome=1">
#     <link rel="stylesheet" rev="stylesheet" href="https://include.anjukestatic.com/aifang/res/2019071206/b/Aifang_Web_Loupan_View2_NewIndex.css" type="text/css" />
# <link rel="stylesheet" rev="stylesheet" href="//pages.anjukestatic.com/kfstouch/icons/Fonts-PC-XF/20190704001/iconfont.css" type="text/css" />
# <link rel="stylesheet" rev="stylesheet" href="//pages.anjukestatic.com/kfstouch/js/swiper-4.0.7/swiper.min.css" type="text/css" />
#     <script type="text/javascript">var PAGESTART = +new Date();var __base_url =""</script>
#
#
#             <link rel="shortcut icon" href="//pages.anjukestatic.com/xinfang/favicon.ico" />
#         <!-- INIT START -->
# <script type="text/javascript">
#     var anjuke_web_global_InitTracker=function(city_id,city_cookie_name,guid_cookie_name,base_domain,cookie_path){
#         var expire=365*5;
#         var guid=this.getCookie(guid_cookie_name);
#         if(null==guid){
#             guid=this.createGuid();this.setCookie(guid_cookie_name,guid,expire,cookie_path,base_domain);
#         }else{
#             this.setCookie(guid_cookie_name,guid,expire+1,cookie_path,base_domain);
#         }
#         if(city_id!=this.getCookie(city_cookie_name)){
#             this.setCookie(city_cookie_name,city_id,expire,cookie_path,base_domain);
#         }
#         var session_cookie_name='sessid';var session_id=this.getCookie(session_cookie_name);if(null==session_id){
#             session_id=this.createGuid();this.setCookie(session_cookie_name,session_id,0,cookie_path,base_domain);
#         }
#         this.setCookie('isp', 'true', expire, cookie_path, base_domain);
#     };anjuke_web_global_InitTracker.prototype.createGuid=function(){
#         return(this.S4()+this.S4()+"-"+this.S4()+"-"+this.S4()+"-"+this.S4()+"-"+this.S4()+this.S4()+this.S4());
#     };anjuke_web_global_InitTracker.prototype.S4=function(){
#         return(((1+Math.random())*0x10000)|0).toString(16).substring(1).toUpperCase();
#     };anjuke_web_global_InitTracker.prototype.getCookie=function(check_name){
#         var a_all_cookies=document.cookie.split(';');var a_temp_cookie='';var cookie_name='';var cookie_value='';var b_cookie_found=false;for(i=0;i<a_all_cookies.length;i++){
#             a_temp_cookie=a_all_cookies[i].split('=');cookie_name=a_temp_cookie[0].replace(/^\s+|\s+$/g,'');if(cookie_name==check_name){
#                 b_cookie_found=true;if(a_temp_cookie.length>1){
#                     cookie_value=unescape(a_temp_cookie[1].replace(/^\s+|\s+$/g,''));
#                 }
#                 return cookie_value;break;
#             }
#             a_temp_cookie=null;cookie_name='';
#         }
#         if(!b_cookie_found){
#             return null;
#         }
#     };anjuke_web_global_InitTracker.prototype.setCookie=function(name,value,expires,path,domain,secure){
#         var today=new Date();today.setTime(today.getTime());if(expires){
#             expires=expires*1000*60*60*24;
#         }
#         var expires_date=new Date(today.getTime()+(expires));document.cookie=name+"="+escape(value)+
#             ((expires)?";expires="+expires_date.toGMTString():"")+
#             ((path)?";path="+path:"")+
#             ((domain)?";domain="+domain:"")+
#             ((secure)?";secure":"");
#     };
#     new anjuke_web_global_InitTracker('36','ctid','aQQ_ajkguid','anjuke.com','/');
# </script>
# <!-- INIT END --></head>
# <body class="">
# <div id="header">
#         <!-- 顶部导航 -->
#     <div class="sitenav-warp">
#     <div class="sitenav clearfix">
#         <a class="site-logo fl" href="https://km.anjuke.com" soj="loupan_index_logo">安居客</a>
#         <div class="site-nav fl">
#                                                            <a href="https://km.anjuke.com/">首 页</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.fang.anjuke.com/">新 房</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.anjuke.com/sale/">二手房</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.zu.anjuke.com/">租 房</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.sydc.anjuke.com/xzl-zu/">商铺写字楼</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://haiwai.anjuke.com">海外地产</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.news.anjuke.com/">楼 讯</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://ai.anjuke.com/?action=hydc">房产研究院</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.anjuke.com/market/">房 价</a>
#                                   <span class="line">|</span>
#                                                                  <a href="https://km.anjuke.com/ask/">问 答</a>
#                                                      </div>
#         <div id="j-site-login" class="fr">
#             <!-- 用户登录前 -->
#             <div class="site-user">
#                 <div class="drop-user">
#                     <a href="javascript:">
#                         <span>客户登录</span>
#                         <i class="i-triangle"></i>
#                     </a>
#                     <!-- 客户登录下拉 -->
#                     <div class="site-userlist" style="display: none;">
#                         <a href="https://vip.anjuke.com" target="_blank" rel="nofollow">中国网络经纪人</a>
#                         <a href="https://svip.fang.anjuke.com" target="_blank" rel="nofollow">房易通</a>
#                     </div>
#                 </div>
#                 <span class="line">|</span>
#                 <a href="https://login.anjuke.com/login/form?history=aHR0cHM6Ly9rbS5mYW5nLmFuanVrZS5jb20vbG91cGFuLzI1NTY5Ni5odG1s" target="_blank" rel="nofollow"><i class="hicon hicon-user"></i>用户登录</a>
#                 <a href="https://user.anjuke.com/register/?from=HeaderTop" class="reg" target="_blank" rel="nofollow">注册</a>
#                 <span class="line">|</span>
#                 <!-- 收藏夹 -->
#                 <a href="https://user.anjuke.com/my/login?history=aHR0cHM6Ly91c2VyLmFuanVrZS5jb20vbWFya2VkLw==" class="drop-fav" rel="nofollow"><i class="hicon hicon-heart"></i>收藏夹</a>
#             </div>
#             <!-- 用户登录后 -->
#             <ul class="site-user-login"></ul>
#
#         </div>
#     </div>
# </div><!-- 顶部搜索 -->
#     <!-- 顶部搜索 -->
#     <div class="site-search clearfix">
#         <div class="crumb-item fl">
#     <a href="https://km.anjuke.com" soj="loupan_index_crumb">昆明安居客</a>
# <em>></em>    <a href="https://km.fang.anjuke.com" soj="loupan_index_crumb">昆明楼盘</a>
# <em>></em>    <a href="https://km.fang.anjuke.com/loupan/panlongqu/" soj="loupan_index_crumb">盘龙区楼盘</a>
# <em>></em>    <a href="https://km.fang.anjuke.com/loupan/panlongqu_16141/" soj="loupan_index_crumb">北京路延长线楼盘</a>
# <em>></em>    <a href="https://km.fang.anjuke.com/loupan/255696.html" soj="loupan_index_crumb">融城昆明湖</a>
# </div>                    <div class="map-search">
# 	<a  class="map-tab item-on" href=https://km.fang.anjuke.com/map/loupan/ soj="af_map_loupanlist" target="_blank"><i class="list-ico map-ico"></i>地图找房</a>
# </div>                <div class="search-box " id="j-search">
#     <form class="search-form" method="GET" action="https://km.fang.anjuke.com/loupan/s">
#                 <input class="input-search" type="text" name="kw" maxlength="100" autocomplete="off" value="">
# 		<input class="btn-search" type="button" value='搜索' id="search-btn">
#         <ul class="search-autocomplete old-search">
#         </ul>
#                 <!-- 阻止enter键自动提交表单 -->
#         <input type="text" name="" style="display: none">
# 	</form>
# </div>
#             <div class="hot-search-box" id="j-hot-search">
#         <h3>热门楼盘</h3>
#                 <ul class="hot-list">
#                                                                                                     <li data-href="https://km.fang.anjuke.com/loupan/254373.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">恒大金碧天下</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/255677.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">恒大昆海湖</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/416045.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">恒大玖珑湾</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/422040.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">米兰春天</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/444805.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">华夏四季</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/444898.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">碧桂园东园</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/447509.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">古滇未来城</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/456687.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">北科建春城大观</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                                                                         <li data-href="https://km.fang.anjuke.com/loupan/457446.html" data-soj="loupanlist_sstj">
#                                                 <span class="lp-name">华侨城 公园悦府</span>
#                                                 <em class="plate"> </em>
#                                             </li>
#
#                                     </ul>
#     </div>
#     </div><!-- 楼盘Tab 列表页去掉TAB，根据$data->type来判断-->
#
#   <!-- 包含头部广告位与tab -->
# <!-- 头图 -->
# <!-- tab导航 -->
# <div class="lp-navtabs-warp " ">
#     <div class="lp-nav">
#         <ul class="lp-navtabs clearfix">
#                                                     <li><a href="https://km.fang.anjuke.com/loupan/255696.html"  class="item-focus"  soj="loupan_tab">  楼盘首页</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/canshu-255696.html"  soj="loupan_tab">  楼盘详情</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/xiangce-255696.html"  soj="loupan_tab">  楼盘相册</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/officialnews-255696.html"  soj="loupan_tab">  楼盘动态</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/huxing-255696.html"  soj="loupan_tab">  楼盘户型</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/dianping-255696.html"  soj="loupan_tab">  用户点评</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/wenda-255696.html"  soj="loupan_tab">  问答</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/tanpan-255696.html"  soj="loupan_tab">  楼盘评测</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/ditu-255696.html"  soj="loupan_tab">  周边配套</a></li>
#                                                                     <li><a href="https://km.fang.anjuke.com/loupan/fangyuan-255696.html"  soj="loupan_tab">  楼盘房源</a></li>
#                                     </ul>
#     </div>
# </div>
#
# </div>
# <div id="container">
#     <!-- ++++++++ 第1屏 ++++++++ -->
# <div class="main-detail mod">
#     <span id="need_dynamic_400_tel" value="0"></span>
#     <div id="j-switch-basic" class="switch">
#         <div class="switch-box">
#             <div id="jp_container_1" class="video-wrap jp-video" role="application" aria-label="media player">
#     <div class="jp-state-dialog jp-networkError-dialog">
#         <div class="jp-state-bg"></div>
#         <div class="jp-state-cont">
#             <i class="jp-icon-loading"></i>
#             <span class="jp-state-text">视频加载中</span>
#         </div>
#     </div>
#     <div class="jp-type-single">
#         <div id="jquery_jplayer_1" class="jp-jplayer"></div>
#         <div class="jp-gui">
#             <div class="jp-video-play">
#                 <a class="jp-video-play-icon" role="button" tabindex="0">play</a>
#             </div>
#             <div class="jp-interface">
#                 <div class="jp-progress">
#                     <div class="jp-seek-bar">
#                         <div class="jp-play-bar"></div>
#                     </div>
#                 </div>
#                 <div class="jp-controls-holder">
#                     <div class="jp-controls">
#                         <a class="jp-play jp-icon" role="button" tabindex="0">play</a>
#                     </div>
#                     <div class="jp-times"><span class="jp-current-time" role="timer" aria-label="time">&nbsp;</span><span class="jp-all-time"></span></div>
#                     <div class="jp-toggles">
#                         <a title="循环播放" class="jp-repeat jp-icon" role="button" toggle="true" tabindex="0">repeat</a>
#                         <a class="jp-full-screen jp-icon" role="button" tabindex="0">full screen</a>
#                     </div>
#                     <div class="jp-volume-controls">
#                         <a class="jp-mute jp-icon" role="button" tabindex="0">mute</a>
#                         <a class="jp-volume-max jp-icon" role="button" toggle="true" tabindex="0">max volume</a>
#                         <div class="jp-volume-bar">
#                             <div class="jp-volume-bar-value" style="width: 80%;"></div>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#         <div class="jp-no-solution">
#             <span>需要升级</span>您的浏览器版本过低，或需要安装新版flash<a href="http://get.adobe.com/flashplayer/" target="_blank">Flash plugin</a>.
#         </div>
#     </div>
# </div>
#
#             <div class="clip">
#                 <div class="con">
#                                                 <a href="javascript:;" class="item-video-a" >
#                                 <div style="display: block;" class="item item-video" data-duration="01:11" data-id="1237115">
#                                     <i class="icon-video"></i>
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/da15f949a89518741a01a10912c3d9de/600x450x98c.jpg" src="https://pic4.ajkimg.com/display/xinfang/da15f949a89518741a01a10912c3d9de/600x450x98c.jpg" width="600" height="450" alt=""/>
#                                 </div>
#                             </a>
#                                                                         <a href="https://km.fang.anjuke.com/loupan/xiangce-255696/xgt.html" target="_blank" soj="loupan_view_photo">
#                                 <div  class="item" image_id="2342719">
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/ec0de825c91d7557bb6571f6b09dd676/600x450x98c.jpg"  width="600" height="450" alt="融城昆明湖楼盘建筑物外景"/>
#                                 </div>
#                             </a>
#                                                                         <a href="https://km.fang.anjuke.com/loupan/xiangce-255696/ght.html" target="_blank" soj="loupan_view_photo">
#                                 <div  class="item" image_id="2365697">
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/b5b74a01cce3da8e9e8be22cf01ecdfb/600x450x98c.jpg"  width="600" height="450" alt="融城昆明湖规划沙盘"/>
#                                 </div>
#                             </a>
#                                                                         <a href="https://km.fang.anjuke.com/loupan/xiangce-255696/ybj.html" target="_blank" soj="loupan_view_photo">
#                                 <div  class="item" image_id="2342707">
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/07b9920ff0510fcfb90fd22f6bf33e7e/600x450x98c.jpg"  width="600" height="450" alt="融城昆明湖"/>
#                                 </div>
#                             </a>
#                                                                         <a href="https://km.fang.anjuke.com/loupan/xiangce-255696/wzt.html" target="_blank" soj="loupan_view_photo">
#                                 <div  class="item" image_id="2365701">
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/20728903954872aeab65353fa6240d15/600x450x98c.jpg"  width="600" height="450" alt="融城昆明湖楼盘区位规划"/>
#                                 </div>
#                             </a>
#                                                                         <a href="https://km.fang.anjuke.com/loupan/xiangce-255696/ptt.html" target="_blank" soj="loupan_view_photo">
#                                 <div  class="item" image_id="2342853">
#                                     <img data-src="https://pic4.ajkimg.com/display/xinfang/73a57416a264725bed5534eaa8e0be5a/600x450x98c.jpg"  width="600" height="450" alt="融城昆明湖楼盘周边配套"/>
#                                 </div>
#                             </a>
#                                                             </div>
#             </div>
#             <a class="arrow arrow-pre">
#                 <i class="lp-icons"></i>
#             </a>
#             <a class="arrow arrow-next">
#                 <i class="lp-icons"></i>
#             </a>
#         </div>
#         <div class="snav">
#                             <a href="javascript:" class="pnav cur">
#                     <img width="88" height="63" src="https://pic4.ajkimg.com/display/xinfang/da15f949a89518741a01a10912c3d9de/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">视频</em>                </a>
#                             <a href="javascript:" class="pnav ">
#                     <img width="90" height="65" src="https://pic4.ajkimg.com/display/xinfang/ec0de825c91d7557bb6571f6b09dd676/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">楼盘图</em>                </a>
#                             <a href="javascript:" class="pnav ">
#                     <img width="90" height="65" src="https://pic4.ajkimg.com/display/xinfang/b5b74a01cce3da8e9e8be22cf01ecdfb/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">沙盘图</em>                </a>
#                             <a href="javascript:" class="pnav ">
#                     <img width="90" height="65" src="https://pic4.ajkimg.com/display/xinfang/07b9920ff0510fcfb90fd22f6bf33e7e/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">样板间</em>                </a>
#                             <a href="javascript:" class="pnav ">
#                     <img width="90" height="65" src="https://pic4.ajkimg.com/display/xinfang/20728903954872aeab65353fa6240d15/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">位置图</em>                </a>
#                             <a href="javascript:" class="pnav ">
#                     <img width="90" height="65" src="https://pic4.ajkimg.com/display/xinfang/73a57416a264725bed5534eaa8e0be5a/90x65m.jpg">
#                     <span class="tit-bg"></span>
#                     <em class="photo-tit">配套图</em>                </a>
#                     </div>
#     </div>
#     <div class="basic-details">
#         <div class="basic-parms-wrap">
#             <div class="clearfix">
#                 <div class="basic-info">
#                     <h1>融城昆明湖</h1>
#                                         <p class="lp-alias g-overflow">别名：城投湖畔四季城</p>
#                                         <div class="tags">
#                         <a class="lp-type">
#                             住宅                        </a>
#                         <!-- 售卖状态：待售/在售/售罄分别判断对应相应class -->
#                                                 <a class="on-sale">在售</a>
#                                                                                                                            <a>项目在建</a>
#                                                    <a>品牌开发商</a>
#                                                    <a>高绿化率</a>
#                                                    <a>车位充足</a>
#                                                    <a>公园</a>
#                                             </div>
#                                     </div>
#                 <div class="wchar-qr">
#                     <img id="qr-pos" width="120" height="120" />
#                     <p>微信扫码，浏览更便捷</p>
#                 </div>
#             </div>
#             <dl class="basic-parms clearfix">
#                 <dt>价格</dt>
#                 <dd class="price">
#                     <p>
#                                                     <em class="sp-price other-price">14500</em><span>元/㎡</span>
#                                                                             <a href="javascript:" id="j-bianjia-note"
#                                data-loupan_id="255696"
#                                class="subscribe-link showlink notice-link toright"
#                                data-soj="loupan_index_bianjia"
#                                data-soj58="xfindex_bjorder_click"
#                                data-sojCustom='{"property_type":"住宅"}'
#                                sub-data="1">
#                                 <i class="iconfont lp-icons-notice">&#xebf4;</i>变价通知我
#                             </a>
#                                             </p>
#                 </dd>
#                                 <dt>开盘</dt>
#                 <dd><span>2018-04-15</span>
#                                             <a class="showlink subscribe-link toright" id="j-open-showlink"
#                            href="javascript:" sub-data="3"
#                            data-click_soj="loupan_index_kaipan"
#                            data-loupan_id="255696"
#                            data-soj58="xfindex_kporder_click"
#                            data-sojCustom='{"property_type":"住宅"}'
#                         <i class="lp-icons lp-icons-open"></i>
#                         <i class="iconfont lp-icons-open">&#xebf3;</i>开盘通知我
#                         </a>
#                                     </dd>
#                                                 <dt>交房</dt>
#                 <dd>
#                     <span>2020年7月31日   </span>
#                 </dd>
#                                                 <dt>户型</dt>
#                 <dd class="ajust">
#                     <div class="house-item g-overflow">
#                                                 <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=2" soj="loupan_index_huxing" target="_blank">二室(3)</a>，<a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=3" soj="loupan_index_huxing" target="_blank">三室(8)</a>，<a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=4" soj="loupan_index_huxing" target="_blank">四室(4)</a>                    </div>
#                     <a class="showlink toright huxing-icon" id="j-housetype-showlink" href="https://km.fang.anjuke.com/loupan/huxing-255696.html"
#                         target="_blank" soj="loupan_index_first_huxing">
#                         <i class="iconfont lp-icons-housetype">&#xebf2;</i>全部户型
#                     </a>
#                 </dd>
#                                 <dt class="last-line">地址</dt>
#                 <dd class="last-line g-overflow">
#                                     <a class="lpAddr-text g-overflow" href="https://km.fang.anjuke.com/loupan/ditu-255696.html" soj="loupan_index_map" target="_blank">[ 盘龙区 - 北京路延长线 ] 龙江西路,近盘江西路                    </a>
#                     <a class="showlink toright addr-map" href="https://km.fang.anjuke.com/loupan/ditu-255696.html" soj="loupan_index_map" target="_blank">
#                         <i class="iconfont lp-icons-map">&#xebf5;</i>查看地图
#                     </a>
#                 </dd>
#             </dl>
#         </div>
#         <div class='more-info'>
#                                             <a href="https://km.fang.anjuke.com/loupan/canshu-255696.html" class="showlink loupanmore" target="_blank" soj="loupan_index_more">查看更多楼盘详情&nbsp;<i class="iconfont">&#xea1e;</i></a>
#                                     </div>
#         <!-- 楼盘电话 -->
#                                     <div class="basic-tel " id="j-triggerlayer-b" style="opacity:1" data-phone='{"hasPhone":"0","soj":"click_ld_lpsy_callbottom","isShow":"1","params":{"loupanId":"255696"}}'>
#                 <i class="iconfont lp-icons-tel">&#xea65;</i>
#                                     <div class="tel-box glance-mod" id="phone_show_soj" data-trace="Exp_Xinfang_pc_tel-box">
#                         <p class="tel clearfix">
#                             <strong>400 603 2266</strong><em>转</em>
#                             <strong id="phone_num_basic" class="last-strong">64678</strong>
#                             <input type=hidden value="#phone_num_basic" class="replace_phone_400"/>
#                                                                                                 <a href="javascript:" class="btn btn-a" id="j-btn-mfth" style="display: none;">致电售楼处</a>
#                                     <a href="javascript:" class="btn btn-a" id="j-btn-ljth" style="display: none;">立即通话</a>
#                                     <a href="javascript:" class="btn btn-a" id="j-btn-yyhd" style="display: none;">预约回电</a>
#                                                                                     </p>
#                     </div>
#                     <div class="tel-tip">安全通话隐藏真实号码，致电售楼处了解更多信息</div>
#                             </div>
#                 <!-- 售罄楼盘的订阅 -->
#             </div>
# </div>
# <!-- 优惠通知我 -->
# <!--弹出窗  优惠通知我 第一步-->
# <div class="discount-notice-bd" style="display: none;">
#     <div class="apply-form">
#         <p class="gray">请填写获取优惠通知的联系方式：</p>
#
#         <div class="tel-info">
#             <label><em>*</em>手机号码：</label>
#
#             <div class="tel-box">
#                 <input type="text" class="int-text int-text-max" value="请输入您的手机号码" maxlength="11"/>
#                 <span class="com-msg" style="display:none;"></span>
#             </div>
#         </div>
#         <div class="btn-box">
#             <a href="javascript:" class="btn btn-b">立即提交</a>
#         </div>
#     </div>
# </div>
#
#
#
# <!--弹出窗  线路看房报名 成功-->
# <div class="discount-result-bd" style="display: none;">
#     <dl class="apply-tips">
#         <dt><i class="lp-icons ok-tips-icon"></i>提交成功！</dt>
#         <dd>我们会第一时间通知您“<span>融城昆明湖</span>”的优惠信息</dd>
#     </dl>
#     <dl class="apply-tips">
#         <dt>
#             <i class="lp-icons err-tips-icon"></i>提交失败！
#         </dt>
#         <dd>非常抱歉提交失败，请稍后重新尝试提交</dd>
#     </dl>
# </div>
# <!-- 优惠通知我 结束 -->
#
# <!-- 开盘通知我 -->
# <!--弹出窗  开盘通知我 第一步-->
# <div class="open-notice-bd" style="display: none;">
#     <div class="open-form clearfix">
#         <i class="lp-icons lp-phone-sub"></i>
#         <div class="sub-main">
#             <p class="sub-title">请填写您接收“融城昆明湖”开盘通知的手机号码</p>
#             <div class="sub-info">
#                 <label><em>*</em>&nbsp;手机号码：</label>
#                 <input type="text" class="int-text int-text-max" value="请输入您的手机号码" maxlength="11" />
#                 <span class="com-msg" style="display: none;"></span>
#             </div>
#             <a href="javascript:" class="btn btn-b">立即确认</a>
#         </div>
#     </div>
# </div>
# <!--弹出窗  开盘通知我报名 成功-->
# <div class="open-result-bd" style="display: none;">
#     <p class="notice-tips open-notice-ok"><i class="lp-icons ok-tips-icon"></i>您已成功订阅！</p>
#     <p class="notice-tips open-notice-err"><i class="lp-icons err-tips-icon"></i>非常抱歉，订阅失败！</p>
# </div>
# <!-- 开盘通知我 结束 -->
#
# <!-- 置业顾问 -->
# <div class="consultant-mod">
#     <div class="main-title">
#        <h3 class="hd">置业顾问</h3>
#         <span class="description">为您提供以下服务：区域导购&nbsp;政策解读&nbsp;户型解析</span>
#        <div class="fr">
#                  </div>
#     </div>
#     <div class="mod consult-mod ">
#         <div class="consult-wrap">
#             <ul class="consult-list clearfix">
#                             <li class="clearfix">
#                   <img class="photo"
#                   src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="60"
#                   imglazyload-src="https://pic1.ajkimg.com/display/xinfang/67e88cb82776edb61442a8715506922a/80x80c.jpg" />
#                     <div class="consult-info consult-middle" consultant_id="201732" type="1" >
#                       <div class="con-name">
#                           杨新弟                                                                                                    </div>
#                                                                       <!--商铺单页的预约置业顾问按钮 $is_commercial不修改-->
#                         <a href="javascript:"
#                            data-consultant_id="201732"
#                            data-vl_id="2049728945"
#                            data-loupan_id="255696"
#                            data-type="1"
#                                                        class="book-btn consult-btn consult-weappQR "><i class="online-serve iconfont">&#xebd8;</i>在线咨询</a>
#                         <div class="show_QRpic"><div class="white-wall"><img alt="小程序二维码"><p>微信扫一扫,在线聊</p></div></div>
#                    </div>
#                </li>
#                              <li class="clearfix">
#                   <img class="photo"
#                   src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="60"
#                   imglazyload-src="https://pic1.ajkimg.com/display/xinfang/eddda0d5438be47befb9e5ad86b370b4/80x80c.jpg" />
#                     <div class="consult-info consult-middle" consultant_id="201814" type="2" >
#                       <div class="con-name">
#                           郭影                                                                                                    </div>
#                                                                       <!--商铺单页的预约置业顾问按钮 $is_commercial不修改-->
#                         <a href="javascript:"
#                            data-consultant_id="201814"
#                            data-vl_id="2049734347"
#                            data-loupan_id="255696"
#                            data-type="2"
#                                                        class="book-btn consult-btn consult-weappQR "><i class="online-serve iconfont">&#xebd8;</i>在线咨询</a>
#                         <div class="show_QRpic"><div class="white-wall"><img alt="小程序二维码"><p>微信扫一扫,在线聊</p></div></div>
#                    </div>
#                </li>
#                            </ul>
#         </div>
#     </div>
# </div>
#
# <!-- ++++++++ 第2屏 start ++++++++ -->
#
#     <div class="clearfix">
#         <!-- 最新优惠与最新活动 云聚客(异步加载'Aifang_Web_Loupan_View2_Index_NewDiscountV2') -->
#         <div class="async-module discount-box"></div>
#
#         <!-- 获取优惠与立即报名存数据(放入异步加载模块中) -->
#                 <!-- 看房团-专车看房、线路看房(异步加载'Aifang_Web_Loupan_View2_Index_ActivityV2') -->
#         <div class="async-module kft-box"></div>
#     </div>
# <div class='resource-ifx' data-resource_id='1320080' data-city_id=36 data-limit='5' data-loupan_id=255696 data-from='zybh-pc-8'></div><!-- ++++++++ 第2屏 end ++++++++ -->
#
# <!-- ++++++++ 第3屏 start ++++++++ -->
#
#
#
# <div id="news-divid">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div class="clearfix user-clear">
#         <div class="fl short" id="loupanview-dongtai" data-trace='{"loupan_id":"255696"}' data-action="xfindex_kaipanjiaofang_show">
#         <div class="main-title clearfix">
#             <h3 class="hd">楼盘动态</h3>
#                         <a href="https://km.fang.anjuke.com/loupan/officialnews-255696.html" target="_blank" class="more" soj="loupan_index_news">查看全部&nbsp;<i class="iconfont">&#xea1e;</i></a>
#         </div>
#         <div class="dongtai-mod mod">
#             <div class="inner-trend">
#                 <ul>
#                                     <li class="first-dt">
#                         <a class="dt-item" href="https://km.fang.anjuke.com/loupan/news-255696/6979577.html" target="_blank" soj="loupan_index_news">
#                             <div class="g-overflow"><span class="category">楼盘新闻</span><span class="g-overflow dt-tit">观景大平层昆明湖·湖珀，限量发售。</span></div>
#                                                         <div class="else-dt-info clearfix">
#                                                                 <div class="dt-image-wrap">
#                                                                             <img width="100" height="75"
#                                         src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg"
#                                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/a3cb740913c28eb5850ca8301ced4d65/100x75c.jpg" />
#                                                                                                             </div>
#
#                                                                     <div class="consultant-wrap">
#                                         <img width="16" height="16" src="https://pic1.ajkimg.com/display/xinfang/67e88cb82776edb61442a8715506922a/80x80c.jpg"
#                                         class="avator-img" />
#                                         <span>杨新弟</span>
#                                         <label
#                                         data-consultant_id="201732"
#                                         data-vl_id="2049728945"
#                                         data-loupan_id="255696"
#                                         class="dt-consult-btn consult-dt"
#                                         ><i class="online-serve iconfont">&#xebd8;</i>在线咨询</label>
#                                         <div class="dt_show_QRpic"><div class="white-wall"><img alt="小程序二维码"><p>微信扫一扫,在线聊</p></div></div>
#                                     </div>
#
#                             </div>
#                         </a>
#                     </li>
#                                     <li class="">
#                         <a class="dt-item" href="https://km.fang.anjuke.com/loupan/news-255696/6807415.html" target="_blank" soj="loupan_index_news">
#                             <div class="g-overflow"><span class="category">楼盘新闻</span><span class="g-overflow dt-tit">——融城·昆明湖·湖珀——
# 一梯一户大平层限量版的户型发售。</span></div>
#                                                         <div class="else-dt-info clearfix">
#                                                                 <div class="dt-image-wrap">
#                                                                             <img width="100" height="75"
#                                         src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg"
#                                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/a56f4effe54dde68a554c189d601fa46/100x75c.jpg" />
#                                                                                                                     <img width="100" height="75"
#                                         src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg"
#                                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/df1b35f6f984f48dc747713bd038245d/100x75c.jpg" />
#                                                                                                                     <img width="100" height="75"
#                                         src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg"
#                                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/1fac14ad8cb3bcf57484b5f786f04423/100x75c.jpg" />
#                                                                                     <label>共9张</label>
#                                                                                                             </div>
#
#                                                                     <div class="consultant-wrap">
#                                         <img width="16" height="16" src="https://pic1.ajkimg.com/display/xinfang/67e88cb82776edb61442a8715506922a/80x80c.jpg"
#                                         class="avator-img" />
#                                         <span>杨新弟</span>
#                                         <label
#                                         data-consultant_id="201732"
#                                         data-vl_id="2049728945"
#                                         data-loupan_id="255696"
#                                         class="dt-consult-btn consult-dt"
#                                         ><i class="online-serve iconfont">&#xebd8;</i>在线咨询</label>
#                                         <div class="dt_show_QRpic"><div class="white-wall"><img alt="小程序二维码"><p>微信扫一扫,在线聊</p></div></div>
#                                     </div>
#
#                             </div>
#                         </a>
#                     </li>
#                                 </ul>
#             </div>
#         </div>
#     </div>
#         <div class="fr kaipan-wrap" id="loupanview-kaipan" data-trace='{"loupan_id":"255696"}' data-action="xfindex_kaipanjiaofang_show">
#         <div class="main-title clearfix">
#             <h3 class="hd">开盘交房</h3>
#         </div>
#         <div class="kaipan-mod mod">
#             <div class="kp-infos">
#                 <ul>
#                     <label><b></b>开盘</label>
#                                                                 <li class="clearfix">
#                                                 <span>开盘时间待定</span>
#                                                 <span class="kp-des"></span>
#                     </li>
#                                              <li class="clearfix">
#                                                     <span>2018-02-03</span>
#                                                 <span class="kp-des"></span>
#                     </li>
#                                              <li class="clearfix">
#                                                     <span>2018-04-15</span>
#                                                 <span class="kp-des"></span>
#                     </li>
#                                                              </ul>
#                 <ul>
#                     <label><b></b>交房</label>
#                                                                         <li class="clearfix">
#                                                                     <span>2019年7月31号</span>
#                                                             </li>
#                                                     <li class="clearfix">
#                                                                     <span>2019-08-31</span>
#                                                             </li>
#                                                     <li class="clearfix">
#                                                                     <span>2020年7月31日   </span>
#                                                             </li>
#                                                             </ul>
#             </div>
#         </div>
#     </div>
# </div>
# <!-- 等高模块的下边框线 -->
# <div class="clearfix user-clear">
#             <div class="fl fl-line dongtailine"></div>
#         <div class="fr fr-line kaipanline"></div>
# </div>
#     <div id="housetype-divid">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div class="housetype-mod">
#     <div class="main-title">
#         <h3 class="hd">楼盘户型</h3>
#         <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s" target="_blank" class="more" soj="loupan_index">查看全部&nbsp;<i class="iconfont">&#xea1e;</i></a>
#         <div class="fr">
#                         <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=2" target="_blank" soj="loupan_index">2室（3）</a>
#             <span class="line">|</span>
#                         <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=3" target="_blank" soj="loupan_index">3室（8）</a>
#             <span class="line">|</span>
#                         <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=4" target="_blank" soj="loupan_index">4室（4）</a>
#             <span class="line">|</span>
#                         <a href="https://km.fang.anjuke.com/loupan/huxing-255696/s?ca=5" target="_blank" soj="loupan_index">5室（5）</a>
#             <span class="line">|</span>
#                     </div>
#     </div>
#         <div class="housetype mod">
#         <div class="hx-list-mod">
#             <ul class="hx-list">
#                                 <li>
#                     <a href="https://km.fang.anjuke.com/huxing/255696-400714.html" title="" target="_blank" soj="loupan_index_plan_detail">
#                         <img src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="212"
#                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/69d4e4230b1ad20fc32536bbefaae7ab/212x175m.jpg" alt="户型图"/>
#                     </a>
#                     <div class="type-name">
#                             <div class="descrip desc-name">
#                                 <div class="desc-txt clearfix">
#                                 <span class="desc-h">
#                                 F户型</span><!-- 如果大于6个字截断成5个，小于六个字不截 -->
#                                                                 <span class="desc-v">5室2厅3卫</span>
#                                                                 </div>
#                                 <i class="comm-stat hot-sale">主推</i><i class="comm-stat zsale">在售</i>                            </div>
#                             <div class="descrip">
#                                 <span class="desc-k area-k">建筑面积：约178.83m²</span>
#                             </div>
#                         </div>
#                 </li>
#                                 <li>
#                     <a href="https://km.fang.anjuke.com/huxing/255696-196455.html" title="" target="_blank" soj="loupan_index_plan_detail">
#                         <img src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="212"
#                         imglazyload-src="https://pic1.ajkimg.com/display/xinfang/f8e3fd2d282a9d697013859616df2aef/212x175m.jpg" alt="户型图"/>
#                     </a>
#                     <div class="type-name">
#                             <div class="descrip desc-name">
#                                 <div class="desc-txt clearfix">
#                                 <span class="desc-h">
#                                 N2户型</span><!-- 如果大于6个字截断成5个，小于六个字不截 -->
#                                                                 <span class="desc-v">3室2厅2卫</span>
#                                                                 </div>
#                                 <i class="comm-stat hot-sale">主推</i><i class="comm-stat sell-out">售罄</i>                            </div>
#                             <div class="descrip">
#                                 <span class="desc-k area-k">建筑面积：约124.00m²</span>
#                             </div>
#                         </div>
#                 </li>
#                                 <li>
#                     <a href="https://km.fang.anjuke.com/huxing/255696-400718.html" title="" target="_blank" soj="loupan_index_plan_detail">
#                         <img src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="212"
#                         imglazyload-src="https://pic4.ajkimg.com/display/xinfang/2b387a3cafb83ccf85a312db3d5594e0/212x175m.jpg" alt="户型图"/>
#                     </a>
#                     <div class="type-name">
#                             <div class="descrip desc-name">
#                                 <div class="desc-txt clearfix">
#                                 <span class="desc-h">
#                                 1、2、3...</span><!-- 如果大于6个字截断成5个，小于六个字不截 -->
#                                                                 <span class="desc-v">4室2厅3卫</span>
#                                                                 </div>
#                                 <i class="comm-stat zsale">在售</i>                            </div>
#                             <div class="descrip">
#                                 <span class="desc-k area-k">建筑面积：约155.20m²</span>
#                             </div>
#                         </div>
#                 </li>
#                                 <li>
#                     <a href="https://km.fang.anjuke.com/huxing/255696-400713.html" title="" target="_blank" soj="loupan_index_plan_detail">
#                         <img src="https://pages.anjukestatic.com/kfstouch/img/defaut-pic.jpg" width="212"
# ...
#         subAjaxUrl : '//km.fang.anjuke.com/aifang/web/loupan/ajax/subscribebind/',
#         is58PC:false,
#     });
#
#     //模块曝光
#     var exposure = new XF.Exposure();
#     exposure.add($('#sand-district'));//沙盘图
#     exposure.add($('#loupanview_dongtai')); //动态
#     exposure.add($('#loupanview-kaipan'));//开盘交房
#     exposure.add($('#loupanview-around'));//周边配套
#     exposure.add($('#calculator-view'));//参考月供
#     exposure.add($('.guess-list-mod'));//猜你喜欢
#
# (function ($) {
#     $('.footer-plates').css({'border':'1px solid #e0e0e0','margin':'10px 0 0','padding':'7px 20px','text-align':'left'});
#     $('.footer-plates').hide();
#     $('.footer-select').click(function(){
#         $('.footer-plates').hide();
#         $('.'+$(this).attr('plates')+'-plates').show();
#     });
#     $('.footer-infos').mouseleave(function(){
#         setTimeout(function(){$('.footer-plates').hide();},500);
#     });
# })(jQuery)
#
#     new XF.pc.sideBar({
#         loupan_id: '255696'
#     });
#
#         //XF.getWeappQR.Newgetloupanid();
#
# ;(function($) {
#    $(document).ready(function() {
#         window.PhoneActivateBll = new XF.User.PhoneActivate({
#             subAjaxUrl : '//km.fang.anjuke.com/aifang/web/loupan/ajax/subscribebind/',
#             userCenterHost: '//login.anjuke.com/',//用户中心连接
#             phoneBindUri : 'login/iframebindphoneform', //绑定手机号path
#             phoneLoginUri : 'login/iframeform', //用户手机登录path
#             isLogin : false, //用户是否登录
#             isBindPhone : false,//用户手机号
#             isOpenCity : true,//是否是开通城市
#             isSaleOut : false , //是否是售罄
#             isBookingCall : false , //是否预约来电
#             isOneKeySub : false  //是否一键订阅
#         });
#     });
# })(jQuery);
#
# //统一登录退出功能添加history
# ;(function($) {
#     var base64CurrentUrl = "aHR0cDovL2ttLmZhbmcuYW5qdWtlLmNvbS9sb3VwYW4vMjU1Njk2Lmh0bWw=";
#    $(document).ready(function() {
#         var href;
#         if(base64CurrentUrl) {
#             $("body").on("click.logout", "a", function(e) {
#                 var elm = $(this);
#                 if(elm.html() == "退出" && (href = elm.attr("href")) ) {
#                     e.preventDefault();
#                     window.location.href = href + (href.indexOf("?") >= 0 ? "&" : "?") + "history=" + base64CurrentUrl;
#                 }
#             });
#         }
#     });
# })(jQuery);
#
# //<div class="resource-ifx" data-resource_id="1110310" data-regin_id="123" data-subregion_id="444" data-city_id="1312"></div>
# window.AsyncResourceHandle = new window.AsyncResource({
#     url : "//km.fang.anjuke.com/aifang/web/loupan/ajax/resource/"
# });
# </script>
#
# <script type="text/javascript">
#     ;(function() {
#         //页面soj
#                 var op = {Site:'anjuke',Page:'Aifang_Web_Loupan_View2_IndexPage',PageName:'Aifang_Web_Loupan_View2_NewIndexPage',Type:1};
#         var cp = '{"loupan_id":255696,"property_type":"\u4f4f\u5b85"}';
#         var t_params = {target_url:'//s.anjuke.com/stb'};
#         XF.pagename = 'Aifang_Web_Loupan_View2_NewIndexPage';
#         XF.site = 'anjuke';
#         XF.Soj.send(cp,op, t_params);
#     })();
#
#     ;(function() {
#         //isp cookie
#         APF.Utils.setCookie("isp","true",30,"anjuke.com");
#     })();
#
#     var _hmt = _hmt || [];
#     (function() {
#         var hm = document.createElement("script");
#         hm.src = "//hm.baidu.com/hm.js?c5899c8768ebee272710c9c5f365a6d8";
#         var s = document.getElementsByTagName("script")[0];
#         s.parentNode.insertBefore(hm, s);
#     })();
# </script>
# <script type="text/javascript">
#     var xxfwConfig = {
#         namespace:'anjuke_xinfang_c_pc'
#     };
# </script>
# <script type="text/javascript" src='//pages.anjukestatic.com/kfstouch/js/58antiSpider/20180807001/xxfw.min.js'  async defer></script>
# <!--20190714072733-->
# <!-- SEO-百度站长平台自动推送 -->
# <script type="text/javascript">
#
# (function(){
#     var bp = document.createElement('script');
#     var curProtocol = window.location.protocol.split(':')[0];
#     if (curProtocol === 'https'){
#    bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else{
#   bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bp, s);
# })();
# </script>
# <script type="text/javascript">
# window.WMDA_SDK_CONFIG = ({
#     api_v: 1,
#     sdk_v: 0.1,
#     mode: 'report',
#     appid: 8788466729136,
#     key: 'ze5sy1on',
#     project_id: '8788302075828',
#     cookie_domain: document.domain,   //58域下不需要该字段
#     cate_id: '',   //按需填写
#     page_extra: [{   //按需填写
#         key: '',
#         value: ''
#     }],
#     user_extra: [{   //按需填写
#         key: '',
#         value: ''
#     }],
#     channel: '',   //按需填写
#     getUserId: function() {},   //按需填写
#     SPA_HASH: false, //单页应用必选
# });
# </script>
# <script type="text/javascript" src="//j1.58cdn.com.cn/wmda/js/statistic_v000.js"></script>
# <script type="text/javascript">
#     'use strict';
#     var utils=function(t){var e={};function r(n){if(e[n])return e[n].exports;var o=e[n]={i:n,l:!1,exports:{}};return t[n].call(o.exports,o,o.exports,r),o.l=!0,o.exports}return r.m=t,r.c=e,r.d=function(t,e,n){r.o(t,e)||Object.defineProperty(t,e,{enumerable:!0,get:n})},r.r=function(t){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},r.t=function(t,e){if(1&e&&(t=r(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var n=Object.create(null);if(r.r(n),Object.defineProperty(n,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var o in t)r.d(n,o,function(e){return t[e]}.bind(null,o));return n},r.n=function(t){var e=t&&t.__esModule?function(){return t.default}:function(){return t};return r.d(e,"a",e),e},r.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},r.p="",r(r.s=0)}([function(t,e,r){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var n="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(t){return typeof t}:function(t){return t&&"function"==typeof Symbol&&t.constructor===Symbol&&t!==Symbol.prototype?"symbol":typeof t};r(1);var o=r(2),i="application/x-www-form-urlencoded;charset=UTF-8",s="application/json",a={DEFAULT_PARAMS:{method:"GET",contentType:s,credentials:"include"},request:function(t){a._fetch(t)},get:function(t){return t.method="GET",a._fetch(t)},download:function(t){window.open(a.genQueryString(t.url,t.data))},put:function(t){return t.method="PUT",a._fetch(t)},upload:function(t){return new Promise(function(e,r){fetch(t.url,{method:"POST",body:t.data}).then(function(t){var e=t.headers.get("Content-Type"),r=e&&e.indexOf("application/json")>=0;if(!t.ok)return(r?t.json():t.text()).then(function(t){if("string"==typeof t&&(t=t.replace(/<.*?>/gi,"")),"string"==typeof t)throw{code:400,msg:t,message:t};throw t.code=t.code||400,t.msg=t.msg||t.message,t});if(r)return t.json();try{return t.text().then(function(t){try{return JSON.parse(t)}catch(e){return t}})}catch(t){return{code:200,msg:"success"}}}).then(function(t){if("object"===(void 0===t?"undefined":n(t))&&"code"in t&&"msg"in t&&(t.code=+t.code,200!==t.code))throw t.message=t.message||t.msg,t;return t}).catch(function(t){if("string"==typeof t)throw{code:400,msg:t,message:t};throw t.code=t.code||400,t.msg=t.msg||t.message,t}).then(function(r){return t.success&&t.success(r),e(r),r}).catch(function(e){401===e.code?window.location.href="/logout":t.error&&t.error(e),r(e)})})},post:function(t){return t.method="POST",a._fetch(t)},_fetch:function(){var t=arguments.length>0&&void 0!==arguments[0]?arguments[0]:{},e=a.genRequestParams(t);return new Promise(function(r,o){fetch(e.url,e.params).then(function(t){var e=t.headers.get("Content-Type"),r=e&&e.indexOf("application/json")>=0;if(!t.ok)return(r?t.json():t.text()).then(function(t){if("string"==typeof t&&(t=t.replace(/<.*?>/gi,"")),"string"==typeof t)throw{code:400,msg:t,message:t};throw t.code=t.code||400,t.msg=t.msg||t.message,t});if(r)return t.json();try{return t.text().then(function(t){try{return JSON.parse(t)}catch(e){return t}})}catch(t){return{code:200,msg:"success"}}}).then(function(t){if("object"===(void 0===t?"undefined":n(t))&&"code"in t&&"msg"in t&&(t.code=+t.code,200!==t.code))throw t.message=t.message||t.msg,t;return t}).catch(function(t){if("string"==typeof t)throw{code:400,msg:t,message:t};throw t.code=t.code||400,t.msg=t.msg||t.message,t}).then(function(e){return t.success&&t.success(e),r(e),e}).catch(function(e){401===e.code?window.location.href="/logout":t.error&&t.error(e),o(e)})})},genRequestParams:function(t){var e=Object.assign({},a.DEFAULT_PARAMS,t),r=a.genHeader(e),n=e.method.toUpperCase(),o=e.url||"",i=void 0;return"GET"===n&&(o=a.genQueryString(o,e.data)),"POST"===n&&(i=a.genBody(e)),"PUT"===n&&(i=a.genBody(e)),{url:o,params:{method:n,mode:e.mode,headers:r,credentials:e.credentials||"include",body:i}}},genHeader:function(t){r ...
#
# var Fetch = utils.default;
#
# //http://api.fang.anjuke.com/service/applyNum/
#
#
# function initTelPage() {
#     var errTxt = '当前楼盘正忙';
#     var lock = false;
#     function getPhone(param) {
#         var isMobile = arguments.length > 1 && arguments[1] !== undefined ? arguments[1] : '';
#
#         var pre = isMobile ? '/xinfang/api' : __base_url+'';
#         var param2 = {};
#         if (param.loupanId) {
#             param2['loupan_id'] = param.loupanId;
#         }
#         if (param.consultantId) {
#             param2['consultant_id'] = param.consultantId;
#             return Fetch.get({ url: pre + '/dynamic/consultant/phonenum/', data: param2, mode: 'no-cors' });
#         }
#         return Fetch.get({ url: pre + '/dynamic/loupan/phonenum/', data: param2, mode: 'no-cors' });
#         /*return Promise.resolve({
#             data: {
#                 "num": "1111",
#                  "status":'1',
#             }
#           })*/
#     }
#
#     $('[data-phone]').each(function (i, phone) {
#       phone.style.opacity = 1;
#       bindTel(phone);
#     });
#
#     function bindTel(phone) {
#         var phoneConfig = JSON.parse(phone.dataset.phone);
#         var errTxt = '当前楼盘正忙,请稍后再说';
#
#         if (+phoneConfig.hasPhone) {
#             if (+phoneConfig.isShow) {
#                 genPcUi(phone, phoneConfig.ui == 1 ? '致电了解更多信息' : '点击查看售楼处电话', phoneConfig.ui == 1 ? '' : '平台使用隐私加密，保护你的真实号码', phoneConfig.ui);
#                 pcBindTel(phone, phoneConfig);
#             }
#             if (phoneConfig.isMobile) {
#                 mobileBindTel(phone, phoneConfig);
#             }
#         }
#     }
#
#     function pcBindTel(phone, phoneConfig) {
#         phone.onclick = function () {
#             try {
#                 window.XF.Soj.send(phoneConfig.soj, window.XF.Soj.param);
#             } catch (e) {}
#             if (lock) {
#                 return;
#             }
#             lock = true;
#             var tel = '';
#
#             getPhone(phoneConfig.params).then(function (res) {
#                 lock = false;
#                 if (+res.result.status == 0) {
#                     var phoneUi = res.result.num.toString().substring(0, 3) + ' ' + res.result.num.toString().substring(3, 7) + ' ' + res.result.num.toString().substring(7);
#                     genPcUi(phone, phoneUi, '请尽快拨打，如拨打失效请刷新页面重试', phoneConfig.ui);
#                 } else if (+res.result.status == 1) {
#                     if (phoneConfig.ui == '3') {
#                         genPcUi(phone, '<span style="color: #a7a7a7">当前楼盘正忙，请稍后</span>刷新页面重试', '', phoneConfig.ui);
#                     } else {
#                         genPcUi(phone, errTxt, '请稍后刷新页面重试', phoneConfig.ui);
#                     }
#                 }
#             }).catch(function () {
#                 lock = false;
#             });
#         };
#     }
#
#     function mobileBindTel(phone, phoneConfig) {
#         var hrefOrg = null;
#         phone.ontouchstart = function () {
#             if (phone.querySelector('a')) {
#                 hrefOrg = phone.querySelector('a').href;
#                 phone.querySelector('a').onclick = function () {
#                     event.preventDefault();
#                 };
#             }
#             event.preventDefault();
#         };
#         phone.ontouchend = fetchTel;
#
#         function fetchTel() {
#
#             if (lock) {
#                 return;
#             }
#             lock = true;
#             var tel = '';
#             var errTxt = '当前楼盘正忙,请稍后再拨';
#             getPhone(phoneConfig.params, phoneConfig.isMobile).then(function (res) {
#                 lock = false;
#                 if (+res.result.status == 0) {
#                     tel = 'tel:' + res.result.num;
#                     doCall(tel);
#                 } else if (+res.result.status == 1) {
#                     alert(errTxt);
#                 } else if (+res.result.status == 2) {
#                     tel = hrefOrg;
#                     doCall(tel);
#                 }
#             }).catch(function (e) {
#                 lock = true;
#             });
#
#             function doCall(tel) {
#                 if (!phone.querySelector('a')) {
#                     phone.innerHTML += '<a style="visibility:hidden;" href="' + tel + '"></a>';
#                 } else {
#                     phone.querySelector('a').href = '' + tel;
#                 }
#                 requestAnimationFrame(function () {
#                     phone.querySelector('a').onclick = null;
#                     var evt = document.createEvent('MouseEvents');
#                     evt.initMouseEvent('click', false, true);
#                     phone.querySelector('a').dispatchEvent(evt);
#                 });
#             }
#         }
#     }
#
#     function genPcUi(phone, txt, subTxt, ui) {
#         var fragment = document.createDocumentFragment();
#         var main = document.createElement('div');
#         var icon = '<i class="icon-ea65"></i>&nbsp;&nbsp;';
#         var sub = document.createElement('div');
#         main.style.cssText = 'display:flex; justify-content: center; font-weight:bolder;';
#
#         if (ui == 1) {
#             phone.style.className = 'yahei';
#             phone.style.cssText = 'color:white; position:relative;';
#             main.style.cssText += 'padding:0 18px; width:220px; font-size: 18px;background-color: #4A8200;position:absolute; right:0;';
#             sub.style.cssText = 'font-size: 14px;height:100%;position:absolute; transform:translateX(-100%); left:-276px;';
#         } else if (ui == 2) {
#
#             if(location.href.indexOf('huxing')>-1) {
#                 phone.parentNode.style.cssText = 'width:468px;display:flex;justify-content:center;';
#             }
#             if(location.href.indexOf('ditu')>-1) {
#                 phone.parentNode.style.cssText = 'height:92px;display:flex;align-items:center;';
#             }
#             phone.style.cssText = 'padding-right:30px; padding-top:5px;'
#             main.style.cssText += 'width:100%;text-align:center; color:#62ab00; font-size:22px';
#             sub.style.cssText = 'text-align:center;color:#62ab00; width:100%;font-size:14px;';
#         } else if (ui == 3) {
#             main.style.cssText += 'color:#62ab00; font-size:15px; display:inline-block';
#             sub.style.display = "none";
#         } else if (ui == 4) {
#             try {
#                 phone.querySelector('.num').innerHTML = txt;
#                 phone.querySelector('.num').style.fontSize = '1.8rem';
#                 phone.querySelector('.ui-line-overflow').innerHTML = subTxt;
#             } catch (e) {
#                 phone.querySelector('.tel-info').querySelector('span').innerHTML = txt;
#                 phone.querySelector('.tel-info').querySelector('.tel-desc').innerHTML = subTxt;
#             }
#             return;
#         } else {
#             phone.style.cssText = 'background-color:#62ab00; padding: 5px; color:white;text-align:center;';
#             main.style.cssText += 'font-size: 28px;padding-top:5px;';
#             sub.style.cssText = 'font-size: 14px;padding-bottom:6px;';
#         }
#
#         phone.style.cssText += ' cursor: pointer;'
#
#         sub.innerHTML = subTxt;
#         main.innerHTML = icon + txt;
#         phone.innerHTML = '';
#         fragment.appendChild(main);
#         fragment.appendChild(sub);
#         phone.appendChild(fragment);
#     }
# }
#
# initTelPage();
#
# </script>
# </body>
# </html>

# %%
find_url2 = soup.find_all('a',class_ = 'lpAddr-text g-overflow')

string_ = str(find_url2[0])
print(string_)

m = re.findall(r'>(.*?)<', string_)
# Out:
# <a class="lpAddr-text g-overflow" href="https://km.fang.anjuke.com/loupan/ditu-255696.html" soj="loupan_index_map" target="_blank">[ 盘龙区 - 北京路延长线 ] 龙江西路,近盘江西路                    </a>

# %%
print(m)
data_source.loc_desc[1]
# Out:
# ['[ 盘龙区 - 北京路延长线 ] 龙江西路,近盘江西路                    ']
# nan

# %%
# Out:
#   File "<ipython-input-126-229691d4dacb>", line 4
#     m = re.search(r'(?<=-)\w+', 'spam-egg')
#     ^
# SyntaxError: invalid syntax

# %%
for loupan in data_source.name:
    print(loupan)
# Out:
# 骆驼湾
# 融城昆明湖
# 中建龙熙一号
# 新时代广场
# 绿城春江明月
# 中梁首府
# 俊发盛唐城
# 远洋青云府
# 瑞鼎城二期天玺
# 新迎新城
# 东原璞阅
# 碧桂园璟台
# 瀚林澜山
# 中海云麓九里
# 奥园
# 融城春晓
# 世豪香颂时光
# 耀兴枫丹白露
# 实地昆明花鹤翎
# 新希望白麓城
# 和悦铭著
# 君庭云邸
# 金泰国际
# 西城时代西锦里
# 金泰国际III期名门
# 假日城市二期芳华
# 德润香山府
# 万彩城
# 碧桂园龙腾世家
# 英茂瑞景园
# 海伦堡中央广场
# 马街摩尔城
# 润城
# 佳兆业壹号公馆
# 北科建春城大观
# 恒泰滇池名门
# 新希望观澜汇
# 筑友双河湾
# 南悦城
# 万科银海泊岸
# 海伦国际
# 红星天铂
# 龙湖半山
# 实力锦雲府
# 昆明呈贡吾悦广场
# 绿地东海岸
# 昆明国贸国际新城
# 中通世纪峯荟花园
# 泛亚城邦
# 招商翰林大观
# 光明璟宸
# 广电苑和园
# 融创微风十里
# 华侨城公园悦府
# 北大资源颐和1898
# 东骧神骏二期
# 领秀知识城国门府
# 兰亭广场
# 金科江湖海
# 大观首府
# 翰林澜山
# 中交金地中央公园
